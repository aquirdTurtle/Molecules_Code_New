# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # I think that some of this is incorrect! Don't Trust!

# %% [markdown]
# Selection Rules:
# $\Delta \phi = 0, \pm1$
# $\mathscr{i}\pm\leftrightarrow\mathscr{i}\mp$
# $\sigma_v\pm\leftrightarrow\sigma_v\pm$

# %%
import Miscellaneous as misc

# %%
import numpy as np

# %%
import random

# %%
fig, ax = plt.subplots(figsize=(10,10))
fs = 24
ax.axis('off')
ax.text(0,0.93,'Selection Rules:\n'+
'$\Delta \phi = 0, \pm1$\n'+
'$\mathscr{i}\pm\leftrightarrow\mathscr{i}\mp$\n'+
'$\sigma_v\pm\leftrightarrow\sigma_v\pm$', fontsize=24)

y_0pp,y_0mp,y_0pm,y_0mm,y_1p,y_1m,y_2p,y_2m,y_3p,y_3m,y_4p,y_4m,y_5p,y_5m = np.linspace(0,1,14)

#colors,_ = misc.getColors(12, cmStr='inferno')
#colors = 'pink', 'red', 'orange', 'yellow','green','cyan','blue','purple', 'brown', 'black','grey', 'red'
#colors,_ = misc.getColors(12, cmStr='gist_rainbow')
colors,_ = misc.getColors(12)
random.shuffle(colors)

ax.text(0,-0.1,'Ground State \nMolecules', fontsize=fs)
ax.text(0,y_0pp,'$0_{\mathscr{i}+}^{\sigma_v+}$', fontsize=fs, color=colors[0])
ax.text(0,y_0mp,'$0_{\mathscr{i}-}^{\sigma_v+}$', fontsize=fs, color=colors[1])
ax.text(0,y_0pm,'$0_{\mathscr{i}+}^{\sigma_v-}$', fontsize=fs, color=colors[2])
ax.text(0,y_0mm,'$0_{\mathscr{i}-}^{\sigma_v-}$', fontsize=fs, color=colors[3])

ax.text(0,y_1p,'$1_{\mathscr{i}+}$', fontsize=fs, color=colors[4])
ax.text(0,y_1m,'$1_{\mathscr{i}-}$', fontsize=fs, color=colors[5])

ax.text(0,y_2p,'$2_{\mathscr{i}+}$', fontsize=fs, color=colors[6])
ax.text(0,y_2m,'$2_{\mathscr{i}-}$', fontsize=fs, color=colors[7])

ax.text(0,y_3p,'$3_{\mathscr{i}+}$', fontsize=fs, color=colors[8])
ax.text(0,y_3m,'$3_{\mathscr{i}-}$', fontsize=fs, color=colors[9])

ax.text(0,y_4p,'$4_{\mathscr{i}+}$', fontsize=fs, color=colors[10])
ax.text(0,y_4m,'$4_{\mathscr{i}-}$', fontsize=fs, color=colors[11])

# Excited State Molecules
ax.text(0.8,-0.1,'Excited \nMolecules', fontsize=fs)
ax.text(0.8,y_0pp,'$0_{\mathscr{i}+}^{\sigma_v+}$', fontsize=fs)
ax.text(0.8,y_0mp,'$0_{\mathscr{i}-}^{\sigma_v+}$', fontsize=fs)
ax.text(0.8,y_0pm,'$0_{\mathscr{i}+}^{\sigma_v-}$', fontsize=fs)
ax.text(0.8,y_0mm,'$0_{\mathscr{i}-}^{\sigma_v-}$', fontsize=fs)

ax.text(0.8,y_1p,'$1_{\mathscr{i}+}$', fontsize=fs)
ax.text(0.8,y_1m,'$1_{\mathscr{i}-}$', fontsize=fs)

ax.text(0.8,y_2p,'$2_{\mathscr{i}+}$', fontsize=fs)
ax.text(0.8,y_2m,'$2_{\mathscr{i}-}$', fontsize=fs)

ax.text(0.8,y_3p,'$3_{\mathscr{i}+}$', fontsize=fs)
ax.text(0.8,y_3m,'$3_{\mathscr{i}-}$', fontsize=fs)

ax.text(0.8,y_4p,'$4_{\mathscr{i}+}$', fontsize=fs)
ax.text(0.8,y_4m,'$4_{\mathscr{i}-}$', fontsize=fs)

ax.text(0.8,y_5p,'$5_{\mathscr{i}+}$', fontsize=fs)
ax.text(0.8,y_5m,'$5_{\mathscr{i}-}$', fontsize=fs)


# Lines
xp = [0.12,0.78]

ax.plot(xp,[y_0pp,y_0mp], color=colors[0]);
ax.plot(xp,[y_0pp,y_1m], color=colors[0]);

ax.plot(xp,[y_0mp,y_0pp], color=colors[1]);
ax.plot(xp,[y_0mp,y_1p], color=colors[1]);

ax.plot(xp,[y_0pm,y_0mm], color=colors[2]);
ax.plot(xp,[y_0pm,y_1m], color=colors[2]);

ax.plot(xp,[y_0mm,y_0pm], color=colors[3]);
ax.plot(xp,[y_0mm,y_1p], color=colors[3]);

ax.plot(xp,[y_1p,y_1m], color=colors[4]);
ax.plot(xp,[y_1p,y_0mp], color=colors[4]);
ax.plot(xp,[y_1p,y_0mm], color=colors[4]);
ax.plot(xp,[y_1p,y_2m], color=colors[4]);

ax.plot(xp,[y_1m,y_1p], color=colors[5]);
ax.plot(xp,[y_1m,y_0pp], color=colors[5]);
ax.plot(xp,[y_1m,y_0pm], color=colors[5]);
ax.plot(xp,[y_1m,y_2p], color=colors[5]);

ax.plot(xp,[y_2p,y_1m], color=colors[6]);
ax.plot(xp,[y_2p,y_2m], color=colors[6]);
ax.plot(xp,[y_2p,y_3m], color=colors[6]);

ax.plot(xp,[y_2m,y_1p], color=colors[7]);
ax.plot(xp,[y_2m,y_2p], color=colors[7]);
ax.plot(xp,[y_2m,y_3p], color=colors[7]);

ax.plot(xp,[y_3p,y_2m], color=colors[8]);
ax.plot(xp,[y_3p,y_3m], color=colors[8]);
ax.plot(xp,[y_3p,y_4m], color=colors[8]);

ax.plot(xp,[y_3m,y_2p], color=colors[9]);
ax.plot(xp,[y_3m,y_3p], color=colors[9]);
ax.plot(xp,[y_3m,y_4p], color=colors[9]);

ax.plot(xp,[y_4p,y_3m], color=colors[10]);
ax.plot(xp,[y_4p,y_4m], color=colors[10]);
ax.plot(xp,[y_4p,y_5m], color=colors[10]);

ax.plot(xp,[y_4m,y_3p], color=colors[11]);
ax.plot(xp,[y_4m,y_4p], color=colors[11]);
ax.plot(xp,[y_4m,y_5p], color=colors[11]);


ax.set_xlim(0,1)
ax.set_ylim(0,1)
# Out:
# (0, 1)
